# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
import json

data = {}
data['people'] = []
data['people'].append({
    'name': 'Scott',
    'website': 'stackabuse.com',
    'from': 'Nebraska'
})
data['people'].append({
    'name': 'Larry',
    'website': 'google.com',
    'from': 'Michigan'
})
data['people'].append({
    'name': 'Tim',
    'website': 'apple.com',
    'from': 'Alabama'
})

with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)

# %%
import json

with open('data.txt') as json_file:
    data = json.load(json_file)
    for p in data['people']:
        print('Name: ' + p['name'])
        print('Website: ' + p['website'])
        print('From: ' + p['from'])
        print('')
# Out:
# Name: Scott
# Website: stackabuse.com
# From: Nebraska
#
# Name: Larry
# Website: google.com
# From: Michigan
#
# Name: Tim
# Website: apple.com
# From: Alabama

# %%
# Информация об одном банкомате содержит
# Ячейку не запускать

{
    
  "id":"324394",
  
  "geolocation":
        {
        "latitude":"55.804936",
        "longitude":"37.589922"
        },
  
  "address": 
        {
        "region":"Москва",
        "regionType":"г",
        "settlementType":"г",
        "settlement":"Москва",
        "fullAddress":"г. Москва, ул. Новодмитровская, д. 2, корп. 1",
        "nearestSubway":" Дмитровская, 660 м",
        "location":"Бизнес Парк \"Савеловский Сити\"",
        "metro":
          [
            {
                "name":"Дмитровская",
                "line":
                        {
                            "name":"Серпуховско-Тимирязевская",
                            "code":"line9"
                        },
                "distance":"660",
                "icon":
                        {"colorScheme":
                            {
                              "primary":"#A1A2A3",
                              "secondary":"#ACBFE0"
                            }
                        }
             }
           ]
         }
  }
# Out:
# {'id': '324394',
#  'geolocation': {'latitude': '55.804936', 'longitude': '37.589922'},
#  'address': {'region': 'Москва',
#   'regionType': 'г',
#   'settlementType': 'г',
#   'settlement': 'Москва',
#   'fullAddress': 'г. Москва, ул. Новодмитровская, д. 2, корп. 1',
#   'nearestSubway': ' Дмитровская, 660 м',
#   'location': 'Бизнес Парк "Савеловский Сити"',
#   'metro': [{'name': 'Дмитровская',
#     'line': {'name': 'Серпуховско-Тимирязевская', 'code': 'line9'},
#     'distance': '660',
#     'icon': {'colorScheme': {'primary': '#A1A2A3', 'secondary': '#ACBFE0'}}}]}}

# %%
ATM = [{"id":"324394","geolocation":{"latitude":"55.804936","longitude":"37.589922"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Новодмитровская, д. 2, корп. 1","nearestSubway":" Дмитровская, 660 м","location":"Бизнес Парк \"Савеловский Сити\"","metro":[{"name":"Дмитровская","line":{"name":"Серпуховско-Тимирязевская","code":"line9"},"distance":"660","icon":{"colorScheme":{"primary":"#A1A2A3","secondary":"#ACBFE0"}}}]}},{"id":"324460","geolocation":{"latitude":"55.524047","longitude":"37.518347"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, Чечёрский пр., 51","nearestSubway":"Бунинская Аллея - 1550 м","location":"ТЦ \"Бутово Молл\"","metro":[{"name":"Бунинская аллея","line":{"name":"Бутовская","code":"line12"},"distance":"1550","icon":{"colorScheme":{"primary":"#ACBFE0","secondary":"#ACBFE0"}}}]}},{"id":"324957","geolocation":{"latitude":"51.863511","longitude":"54.763003"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"п","settlement":"Каргала","fullAddress":"Оренбургская обл., п. Каргала, Подгородне-покровский сельсовет севернее ориентира 29-й км трассы оренбург-самара","location":"Операционный офис №037\/2013 Ф-ла Банка ГПБ (АО) \"Поволжский\""}},{"id":"324959","geolocation":{"latitude":"51.717497","longitude":"55.091279"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, ул. Донгузская, 50","location":"Административное здание Филиала «Оренбург бурение» ООО «Газпром бурение»"}},{"id":"324961","geolocation":{"latitude":"51.775720","longitude":"55.185184"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, пр. Гагарина, 48\/3","location":"ТК \"3 Мартышки\""}},{"id":"324962","geolocation":{"latitude":"51.782296","longitude":"55.217680"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"п","settlement":"Ростоши","fullAddress":"Оренбургская обл., п. Ростоши, ул. Газпромовская, 65","location":"Операционный офис №037\/2014 Ф-ла Банка ГПБ (АО) \"Поволжский\""}},{"id":"324963","geolocation":{"latitude":"51.761702","longitude":"55.101289"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, ул. Пушкинская, 20","location":"Административное здание ООО \"ВолгоУралНИПИгаз\""}},{"id":"324964","geolocation":{"latitude":"51.767750","longitude":"55.092614"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, ул. Постникова, 9б","location":"ООО \"Газпром межрегионгаз Оренбург\""}},{"id":"324967","geolocation":{"latitude":"51.825114","longitude":"55.111087"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, пр. Дзержинского, 2\/2","location":"Административное здание НТЦ \"Промбезопасность\""}},{"id":"324968","geolocation":{"latitude":"51.761260","longitude":"55.106426"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, ул. Правды, 18","location":"Операционный офис №037\/2009 Ф-ла Банка ГПБ (АО) \"Поволжский\""}},{"id":"324970","geolocation":{"latitude":"51.794495","longitude":"55.163759"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, ул. Авторемонтная, 1","location":"ТК \"АвтоМаксимум\""}},{"id":"324971","geolocation":{"latitude":"51.774596","longitude":"55.215595"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, Нежинское шоссе, 11","location":"\"Автосалон - 2000\""}},{"id":"324972","geolocation":{"latitude":"52.792126","longitude":"52.265960"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Бузулук","fullAddress":"Оренбургская обл., г. Бузулук, ул. Ленина, 54","location":"ТЦ \"Империя\""}},{"id":"324973","geolocation":{"latitude":"51.770027","longitude":"55.077422"},"address":{"region":"Оренбургская","regionType":"обл","settlementType":"г","settlement":"Оренбург","fullAddress":"Оренбургская обл., г. Оренбург, пер. Кондукторский, 2","location":"ТК \"Город Локомотив\""}},{"id":"325262","geolocation":{"latitude":"45.263100","longitude":"41.836550"},"address":{"region":"Ставропольский","regionType":"край","settlementType":"п","settlement":"Рыздвяный","fullAddress":"Ставропольский край., п. Рыздвяный, ул. Южная, д.5","location":"\"Газпром трансгаз Ставрополь\" УТТ и СТ"}},{"id":"524263","geolocation":{"latitude":"55.888256","longitude":"37.589363"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, Алтуфьевское шоссе д. 70, корп. 1.","nearestSubway":" Бибирево, 1, 000 м\n Алтуфьево, 1,100 м","location":"ТДЦ «Маркос-Молл»","metro":[{"name":"Бибирево","line":{"name":"Серпуховско-Тимирязевская","code":"line9"},"distance":"1000","icon":{"colorScheme":{"primary":"#A1A2A3","secondary":"#ACBFE0"}}},{"name":"Алтуфьево","line":{"name":"Серпуховско-Тимирязевская","code":"line9"},"distance":"1100","icon":{"colorScheme":{"primary":"#A1A2A3","secondary":"#ACBFE0"}}}]}},{"id":"524266","geolocation":{"latitude":"55.905494","longitude":"37.412824"},"address":{"region":"Московская","regionType":"обл","settlementType":"г","settlement":"Химки","fullAddress":"Московская обл., г. Химки, Г.О. Химки, Ленинградское ш., влад. 21","location":"Автосалон \"РОЛЬФ\""}},{"id":"524268","geolocation":{"latitude":"55.710687","longitude":"37.670465"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. 7-ая Кожуховская, вл. 3А, 5 (ЮВАО)","nearestSubway":" Дубровка - 800 м;\n Кожуховская - 810 м;\n Автозаводская - 1300 м","location":"ТРЦ \"Мозаика\", выход с парковки к супермаркету \"Лента\" (цокольный этаж)","metro":[{"name":"Дубровка","line":{"name":"МЦК","code":"line14"},"distance":"800","icon":{"colorScheme":{"primary":"#F5A0C2","secondary":"#ACBFE0"}}},{"name":"Кожуховская","line":{"name":"Люблинско-Дмитровская","code":"line10"},"distance":"810","icon":{"colorScheme":{"primary":"#B4D445","secondary":"#ACBFE0"}}},{"name":"Автозаводская","line":{"name":"МЦК","code":"line14"},"distance":"1300","icon":{"colorScheme":{"primary":"#F5A0C2","secondary":"#ACBFE0"}}}]}},{"id":"524269","geolocation":{"latitude":"55.608409","longitude":"38.858478"},"address":{"region":"Московская","regionType":"обл","settlementType":"д","settlement":"Давыдово","fullAddress":"Московская обл., д. Давыдово, Орехово-Зуевский район, дер. Давыдово, 2-ой микрорайон","location":"Супермаркет \"Гранд\""}},{"id":"524272","geolocation":{"latitude":"55.719987","longitude":"37.776215"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, Рязанский просп., д. 24, корп. 3","nearestSubway":" Рязанский Проспект - 1132 м;\n Кузьминки - 1746 м;\n Выхино - 2668 м","location":"Автосалон \"РОЛЬФ\"","metro":[{"name":"Рязанский проспект","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"1132","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}},{"name":"Кузьминки","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"1746","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}},{"name":"Выхино","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"2668","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}}]}},{"id":"524273","geolocation":{"latitude":"55.767332","longitude":"37.524228"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, 2-ой Магистральный туп., д. 5А","nearestSubway":" Полежаевская - 1168 м;\n Беговая - 1501 м;\n Международная - 2153 м","location":"Автосалон \"РОЛЬФ\"","metro":[{"name":"Полежаевская","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"1168","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}},{"name":"Беговая","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"1501","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}},{"name":"Международная","line":{"name":"Филевская","code":"line4"},"distance":"2153","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}}]}},{"id":"524274","geolocation":{"latitude":"55.679895","longitude":"37.568497"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Кржижановского,  д. 16, корп. 3","nearestSubway":" Профсоюзная - 446 м;\n Академическая - 917 м;\n Новые Черёмушки - 1404 м","location":"ПАО \"СИБУР Холдинг\", внутренний корпус","metro":[{"name":"Профсоюзная","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"446","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Академическая","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"917","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Новые Черемушки","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"1404","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}}]}},{"id":"524276","geolocation":{"latitude":"55.528798","longitude":"37.194544"},"address":{"region":"Московская","regionType":"обл","settlementType":"д","settlement":"Рогозинино","fullAddress":"Московская обл., д. Рогозинино, п\/о \"Первомайское\", деревня Рогозинино (24 км от МКАД по Киевскому шоссе)","location":"Пансионат \"Империал парк отель & SPA\", ОАО \"ДРУЖБА\", вестибюль"}},{"id":"524279","geolocation":{"latitude":"55.762399","longitude":"37.619117"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Петровка, д. 10","nearestSubway":" Кузнецкий Мост - 354 м;\n Театральная - 545 м;\n Лубянка - 630 м","location":"ТЦ \"Петровский пассаж\", Группа компаний \"BOSCO\"","metro":[{"name":"Кузнецкий мост","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"354","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}},{"name":"Театральная","line":{"name":"Замоскворецкая","code":"line2"},"distance":"545","icon":{"colorScheme":{"primary":"#4CB85E","secondary":"#ACBFE0"}}},{"name":"Лубянка","line":{"name":"Сокольническая","code":"line1"},"distance":"630","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524280","geolocation":{"latitude":"55.724124","longitude":"37.825155"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Вешняковская, д. 18","nearestSubway":"Выхино, 1, 000 м\nРязанский проспект, 2, 100 м\nЛермонтовский проспект, 3, 000 м","location":"ТЦ «Вешняки»","metro":[{"name":"Выхино","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"1000","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}},{"name":"Рязанский проспект","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"2100","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}},{"name":"Лермонтовский проспект","line":{"name":"Таганско-Краснопресненская","code":"line7"},"distance":"3000","icon":{"colorScheme":{"primary":"#8E479B","secondary":"#ACBFE0"}}}]}},{"id":"524282","geolocation":{"latitude":"55.617276","longitude":"37.715622"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, Каширское ш., д. 61, стр. 3А, корп. 1","nearestSubway":"Домодедово, 670 м\nОрехово, 1,500 м\nШипиловская, 1,800 м","location":"АТЦ \"Москва\"","metro":[{"name":"Орехово","line":{"name":"Замоскворецкая","code":"line2"},"distance":"1500","icon":{"colorScheme":{"primary":"#4CB85E","secondary":"#ACBFE0"}}},{"name":"Шипиловская","line":{"name":"Люблинско-Дмитровская","code":"line10"},"distance":"1800","icon":{"colorScheme":{"primary":"#B4D445","secondary":"#ACBFE0"}}}]}},{"id":"524283","geolocation":{"latitude":"55.685320","longitude":"37.540156"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, Ленинский просп., д. 72\/2","nearestSubway":" Университет - 868 м;\n Профсоюзная - 1648 м;\n Новые Черёмушки - 1922 м","location":"Магазин \"Л'Этуаль\"","metro":[{"name":"Университет","line":{"name":"Сокольническая","code":"line1"},"distance":"868","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}},{"name":"Профсоюзная","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"1648","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Новые Черемушки","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"1922","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}}]}},{"id":"524284","geolocation":{"latitude":"55.819392","longitude":"37.578314"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Яблочкова, д. 21А","nearestSubway":" Тимирязевская, 63 м\n Улица Милашенкова, 850 м","location":"ТЦ \"Тимирязевский\"","metro":[{"name":"Тимирязевская","line":{"name":"Серпуховско-Тимирязевская","code":"line9"},"distance":"63","icon":{"colorScheme":{"primary":"#A1A2A3","secondary":"#ACBFE0"}}},{"name":"Улица Милашенкова","line":{"name":"Монорельс","code":"line13"},"distance":"850","icon":{"colorScheme":{"primary":"#0078BF","secondary":"#ACBFE0"}}}]}},{"id":"524287","geolocation":{"latitude":"55.662136","longitude":"37.547046"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Профсоюзная, д. 57","nearestSubway":" Калужская - 750 м;\n Новые Черемушки - 1000 м","location":"АО \"СОГАЗ\"","metro":[{"name":"Калужская","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"750","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Новые Черемушки","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"1000","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}}]}},{"id":"524288","geolocation":{"latitude":"55.837380","longitude":"37.744227"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Лосиноостровская, д. 45, корп. 1","nearestSubway":"Бульвар Рокоссовского, 2 600 м\nЧеркизовская, 3 800 м\nЩёлковская, 4 500 м\n","location":"ФГБУ \"Клиническая больница УД Президента РФ\", Главный корпус","metro":[{"name":"Бульвар Рокоссовского","line":{"name":"Сокольническая","code":"line1"},"distance":"2","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}},{"name":"Черкизовская","line":{"name":"Сокольническая","code":"line1"},"distance":"3","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}},{"name":"Щелковская","line":{"name":"Арбатско-Покровская","code":"line3"},"distance":"4","icon":{"colorScheme":{"primary":"#0078BF","secondary":"#ACBFE0"}}}]}},{"id":"524290","geolocation":{"latitude":"55.321612","longitude":"38.673104"},"address":{"region":"Московская","regionType":"обл","settlementType":"г","settlement":"Воскресенск","fullAddress":"Московская обл., г. Воскресенск, пл. Ленина, д. 5","location":"Магазин \"Технопарк\""}},{"id":"524299","geolocation":{"latitude":"55.659622","longitude":"37.747738"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Перерва, д. 43, корп. 1","nearestSubway":" Братиславская - 176 м;\n Марьино - 1164 м;\n Люблино - 2052 м","location":"ТЦ \"БУМ\", кинотеатр \"Киномакс Солярис\" (3 этаж)","metro":[{"name":"Братиславская","line":{"name":"Люблинско-Дмитровская","code":"line10"},"distance":"176","icon":{"colorScheme":{"primary":"#B4D445","secondary":"#ACBFE0"}}},{"name":"Марьино","line":{"name":"Люблинско-Дмитровская","code":"line10"},"distance":"1164","icon":{"colorScheme":{"primary":"#B4D445","secondary":"#ACBFE0"}}},{"name":"Люблино","line":{"name":"Люблинско-Дмитровская","code":"line10"},"distance":"2052","icon":{"colorScheme":{"primary":"#B4D445","secondary":"#ACBFE0"}}}]}},{"id":"524301","geolocation":{"latitude":"55.789856","longitude":"37.631422"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Трифоновская, д. 57, стр. 3","nearestSubway":" Рижская - 417 м;\n Проспект Мира - 915 м;\n Марьина Роща - 1044 м","location":"ОАО \"ТНТ-Телесеть\" (1 этаж), ОАО \"Газпром-Медиа Холдинг\"","metro":[{"name":"Рижская","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"417","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Проспект Мира","line":{"name":"Кольцевая","code":"line5"},"distance":"915","icon":{"colorScheme":{"primary":"#894E35","secondary":"#ACBFE0"}}},{"name":"Марьина роща","line":{"name":"Люблинско-Дмитровская","code":"line10"},"distance":"1044","icon":{"colorScheme":{"primary":"#B4D445","secondary":"#ACBFE0"}}}]}},{"id":"524308","geolocation":{"latitude":"55.587448","longitude":"37.751933"},"address":{"region":"Московская","regionType":"обл","settlementType":"п","settlement":"Развилка","fullAddress":"Московская обл., п. Развилка, Ленинский район, пос. Развилка","nearestSubway":"Зябликово - 2860 м; Красногвардейская - 3041м; Домодедовская - 3426 м","location":"ООО \"Газпром ВНИИГАЗ\""}},{"id":"524311","geolocation":{"latitude":"55.664472","longitude":"37.599238"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Одесская, д. 2","nearestSubway":"Нахимовский проспект, 710 м\nКаховская, 1, 700 м\nСевастопольская, 1, 800 м","location":"ООО «Гранд Хаус»","metro":[{"name":"Нахимовский проспект","line":{"name":"Серпуховско-Тимирязевская","code":"line9"},"distance":"710","icon":{"colorScheme":{"primary":"#A1A2A3","secondary":"#ACBFE0"}}},{"name":"Каховская","line":{"name":"Каховская","code":"line11a"},"distance":"1700","icon":{"colorScheme":{"primary":"#79CDCD","secondary":"#ACBFE0"}}},{"name":"Севастопольская","line":{"name":"Серпуховско-Тимирязевская","code":"line9"},"distance":"1800","icon":{"colorScheme":{"primary":"#A1A2A3","secondary":"#ACBFE0"}}}]}},{"id":"524312","geolocation":{"latitude":"55.241647","longitude":"37.963945"},"address":{"region":"Московская","regionType":"обл","settlementType":"п","settlement":"Ильинское","fullAddress":"Московская обл., п. Ильинское, Домодедовский р-н, п. Ильинское","location":"Магазин \"Пятерочка\""}},{"id":"524315","geolocation":{"latitude":"55.662512","longitude":"37.223277"},"address":{"region":"Московская","regionType":"обл","settlementType":"г","settlement":"","fullAddress":"Московская обл., г. , Одинцовский р-н., а\/д \"Новый выход на МКАД с федеральной автомобильной дороги М-1 \"Беларусь\" Москва – Минск\", 13,4 км","location":"Пункт взимания платы (ПВП ПК 134), ООО \"Новое качество дорог\""}},{"id":"524318","geolocation":{"latitude":"55.151416","longitude":"37.550360"},"address":{"region":"Московская","regionType":"обл","settlementType":"г","settlement":"","fullAddress":"Московская обл., г. , МО, 94 км Симферопольского ш., правая сторона","location":"АЗС \"Газпромнефть\" № 12"}},{"id":"524322","geolocation":{"latitude":"55.655923","longitude":"37.541505"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Профсоюзная, д. 61 А","nearestSubway":" Калужская - 122 м;\n Новые Черёмушки - 1775 м;\n Беляево - 1795 м","location":"ТЦ \"Калужский\", Детский квартал (1этаж)","metro":[{"name":"Калужская","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"122","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Новые Черемушки","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"1775","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Беляево","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"1795","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}}]}},{"id":"524329","geolocation":{"latitude":"55.746299","longitude":"37.546174"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, наб. Тараса Шевченко, д. 23а","nearestSubway":" Выставочная - 412 м;\n Студенческая - 848 м;\n Международная - 865 м","location":"ООО \"СТРОЙГАЗКОНСАЛТИНГ\"","metro":[{"name":"Выставочная","line":{"name":"Филевская","code":"line4"},"distance":"412","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}},{"name":"Студенческая","line":{"name":"Филевская","code":"line4"},"distance":"848","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}},{"name":"Международная","line":{"name":"Филевская","code":"line4"},"distance":"865","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}}]}},{"id":"524331","geolocation":{"latitude":"55.688862","longitude":"37.540668"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, Ломоносовский просп., д. 15","nearestSubway":" Университет - 555 м;\n Профсоюзная - 1859 м;\n Академическая - 2060 м","location":"Д\/О № 099\/1012 Банка ГПБ (АО) \"Ломоносовский\", зона 24","metro":[{"name":"Университет","line":{"name":"Сокольническая","code":"line1"},"distance":"555","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}},{"name":"Профсоюзная","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"1859","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}},{"name":"Академическая","line":{"name":"Калужско-Рижская","code":"line6"},"distance":"2060","icon":{"colorScheme":{"primary":"#F58232","secondary":"#ACBFE0"}}}]}},{"id":"524335","geolocation":{"latitude":"55.745904","longitude":"37.559910"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Большая Дорогомиловская, д. 5","nearestSubway":" Киевская - 432 м;\n Киевская - 470 м;\n Киевская - 497 м","location":"Магазин \"Л'Этуаль\"","metro":[{"name":"Киевская","line":{"name":"Филевская","code":"line4"},"distance":"432","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}},{"name":"Киевская","line":{"name":"Филевская","code":"line4"},"distance":"470","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}},{"name":"Киевская","line":{"name":"Филевская","code":"line4"},"distance":"497","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}}]}},{"id":"524343","geolocation":{"latitude":"55.752931","longitude":"37.576024"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. Новый Арбат, д. 36, стр. 3","nearestSubway":" Смоленская - 578 м;\n Смоленская - 787 м;\n Краснопресненская - 794 м","location":"ТЦ «Сфера» (-1 этаж)","metro":[{"name":"Смоленская","line":{"name":"Филевская","code":"line4"},"distance":"578","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}},{"name":"Смоленская","line":{"name":"Филевская","code":"line4"},"distance":"787","icon":{"colorScheme":{"primary":"#00C1F3","secondary":"#ACBFE0"}}},{"name":"Краснопресненская","line":{"name":"Кольцевая","code":"line5"},"distance":"794","icon":{"colorScheme":{"primary":"#894E35","secondary":"#ACBFE0"}}}]}},{"id":"524344","geolocation":{"latitude":"55.723460","longitude":"37.585404"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, Фрунзенская наб., д. 30","nearestSubway":" Фрунзенская - 400 м;\n Парк Культуры - 1286 м;\n Спортивная - 1423 м","location":"ОАО \"Росстройэкспо\", павильон № 26 Администрация","metro":[{"name":"Фрунзенская","line":{"name":"Сокольническая","code":"line1"},"distance":"400","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}},{"name":"Парк культуры","line":{"name":"Сокольническая","code":"line1"},"distance":"1286","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}},{"name":"Спортивная","line":{"name":"Сокольническая","code":"line1"},"distance":"1423","icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524346","geolocation":{"latitude":"55.805275","longitude":"37.800874"},"address":{"region":"Москва","regionType":"г","settlementType":"г","settlement":"Москва","fullAddress":"г. Москва, ул. 9-ая Парковая, д. 62","nearestSubway":" Щёлковская - 571 м;\n Первомайская - 1,217 м;\n Измайловская - 2302 м","location":"ТЦ \"Первомайский\" (1 этаж)","metro":[{"name":"Щелковская","line":{"name":"Арбатско-Покровская","code":"line3"},"distance":"571","icon":{"colorScheme":{"primary":"#0078BF","secondary":"#ACBFE0"}}},{"name":"Первомайская","line":{"name":"Арбатско-Покровская","code":"line3"},"distance":"1217","icon":{"colorScheme":{"primary":"#0078BF","secondary":"#ACBFE0"}}},{"name":"Измайловская","line":{"name":"Арбатско-Покровская","code":"line3"},"distance":"2302","icon":{"colorScheme":{"primary":"#0078BF","secondary":"#ACBFE0"}}}]}},{"id":"524366","geolocation":{"latitude":"56.461001","longitude":"43.646712"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"п","settlement":"Лукино","fullAddress":"Нижегородская обл., п. Лукино, автотрасса Нижний Новгород-Иваново, 31-й км, Лукинское лесничество, квартал 9","location":"Пансионат «Волга»"}},{"id":"524370","geolocation":{"latitude":"56.383579","longitude":"41.324932"},"address":{"region":"Владимирская","regionType":"обл","settlementType":"г","settlement":"Ковров","fullAddress":"Владимирская обл., г. Ковров, тер.Ковров-8, 8","location":"в\/ч 30616, КПП"}},{"id":"524372","geolocation":{"latitude":"56.287332","longitude":"43.928210"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, пр-т Ленина,33","nearestSubway":"Заречная","location":"ТЦ \"Муравей\"","metro":[{"name":"Заречная","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524373","geolocation":{"latitude":"56.500527","longitude":"43.605776"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Балахна","fullAddress":"Нижегородская обл., г. Балахна, ул. Лесопильная, 1","location":"ТЦ \"Галактика\""}},{"id":"524374","geolocation":{"latitude":"56.323148","longitude":"44.000093"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул.Пискунова, 3\/5","location":"АО \"ГТНН\""}},{"id":"524377","geolocation":{"latitude":"55.554970","longitude":"45.919398"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"рп","settlement":"Пильна","fullAddress":"Нижегородская обл., рп. Пильна, Пильненское ЛПУМГ","location":"Пильненское ЛПУМГ"}},{"id":"524380","geolocation":{"latitude":"55.221867","longitude":"45.893767"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"с","settlement":"Сеченово","fullAddress":"Нижегородская обл., с. Сеченово, ул.70 лет Октября,13","location":"Гостиница"}},{"id":"524383","geolocation":{"latitude":"56.283496","longitude":"43.890505"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул.Аксакова, 38","location":"ПАО \"Газпром Газораспределение\""}},{"id":"524384","geolocation":{"latitude":"56.315026","longitude":"42.949248"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"п","settlement":"Мулино","fullAddress":"Нижегородская обл., п. Мулино, ул. Новая, 26","location":"М-н \"Райцентр\""}},{"id":"524385","geolocation":{"latitude":"56.247881","longitude":"43.463440"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Дзержинск","fullAddress":"Нижегородская обл., г. Дзержинск, пр. Чкалова, 23","location":"ТЦ \"Юбилейный\""}},{"id":"524386","geolocation":{"latitude":"56.323802","longitude":"43.981031"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Заломова, 2","nearestSubway":"Горьковская","location":"Гостиница \"Азимут\"","metro":[{"name":"Горьковская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524387","geolocation":{"latitude":"56.227554","longitude":"43.400809"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Дзержинск","fullAddress":"Нижегородская обл., г. Дзержинск, ул. Циолковского, 76","location":"ТЦ \"Союз\""}},{"id":"524388","geolocation":{"latitude":"56.303857","longitude":"43.989987"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул.Пушкина, 18","location":"Газпром газораспределение"}},{"id":"524390","geolocation":{"latitude":"56.233394","longitude":"43.436158"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Дзержинск","fullAddress":"Нижегородская обл., г. Дзержинск, ул. Гайдара, 61","location":"ТЦ \"ЦУМ\""}},{"id":"524392","geolocation":{"latitude":"56.187090","longitude":"43.101901"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"п","settlement":"Володарск","fullAddress":"Нижегородская обл., п. Володарск, ул.Мичурина","location":"Проходная птицефабрики"}},{"id":"524393","geolocation":{"latitude":"55.588529","longitude":"44.288744"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"с","settlement":"Елховка","fullAddress":"Нижегородская обл., с. Елховка, ООО \"ННПП\"","location":"ООО \"ННПП\""}},{"id":"524394","geolocation":{"latitude":"54.717641","longitude":"44.822263"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"с","settlement":"Починки","fullAddress":"Нижегородская обл., с. Починки, ул. Советская, 8","location":"Спорткомплекс"}},{"id":"524395","geolocation":{"latitude":"55.554970","longitude":"45.919398"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"рп","settlement":"Пильна","fullAddress":"Нижегородская обл., рп. Пильна, Пильненское ЛПУМГ","location":"Пильненское ЛПУМГ"}},{"id":"524399","geolocation":{"latitude":"55.399873","longitude":"43.820859"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Челюскинцев, 9","location":"НГПУ им.Козьмы Минина (Автозаводский филиал)"}},{"id":"524401","geolocation":{"latitude":"56.240467","longitude":"43.492999"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Дзержинск","fullAddress":"Нижегородская обл., г. Дзержинск, пр-т Ленина, 107","location":"ПАО \"Газпром Газораспределение\""}},{"id":"524403","geolocation":{"latitude":"56.319230","longitude":"43.930600"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, Московское ш., 4е","location":"Автостанция"}},{"id":"524404","geolocation":{"latitude":"56.327061","longitude":"43.846428"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Кстово","fullAddress":"Нижегородская обл., г. Кстово, ул. 40 лет Октября, 13","location":"магазин \"Пятерочка\""}},{"id":"524405","geolocation":{"latitude":"56.249139","longitude":"43.580004"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул.Чаадаева, 12Б","location":"ПАО \"Газпром Газораспределение\""}},{"id":"524406","geolocation":{"latitude":"56.265696","longitude":"43.637464"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Дзержинск","fullAddress":"Нижегородская обл., г. Дзержинск, Менделеева, 2","location":"Сибур-Нефтехим, Центр. проходная"}},{"id":"524410","geolocation":{"latitude":"56.328808","longitude":"44.012930"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Минина, 8б","nearestSubway":"Горьковская","location":"ДО \"Волжский\" Филиала Банка ГПБ (АО) \"Приволжский\"","metro":[{"name":"Горьковская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524412","geolocation":{"latitude":"56.014188","longitude":"45.036451"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Лысково","fullAddress":"Нижегородская обл., г. Лысково, ул. Казанская, 1г","location":"м-н \"Магнит\""}},{"id":"524416","geolocation":{"latitude":"56.455491","longitude":"43.525124"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Балахна","fullAddress":"Нижегородская обл., г. Балахна, п.Гидроторф","location":"з-д \"Биаксплен\", проходная"}},{"id":"524417","geolocation":{"latitude":"56.299011","longitude":"43.997632"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, Конный проезд, 10","location":"ПАО \"Газпром Газораспределение\""}},{"id":"524418","geolocation":{"latitude":"55.758645","longitude":"47.168482"},"address":{"region":"Чувашская (Чувашия)","regionType":"Респ","settlementType":"с","settlement":"Красноармейское","fullAddress":"Чувашская (Чувашия) Респ., с. Красноармейское, ул.Ленина, 98","location":"Физкультурно-оздоровительный комплекс"}},{"id":"524420","geolocation":{"latitude":"56.347799","longitude":"43.870934"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Коминтерна, 105","nearestSubway":"Буревестник","location":"ТЦ \"Золотая Миля\"","metro":[{"name":"Буревестник","line":{"name":"Сормовско-Мещерская","code":"line1"},"icon":{"colorScheme":{"primary":"#0078BF","secondary":"#ACBFE0"}}}]}},{"id":"524421","geolocation":{"latitude":"56.239503","longitude":"43.863936"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Веденяпина, 2Б","nearestSubway":"Парк Культуры","location":"ТЦ \"Парк-Авеню\"","metro":[{"name":"Парк Культуры","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524422","geolocation":{"latitude":"56.323263","longitude":"44.012095"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Ковалихинская, 8","nearestSubway":"Горьковская","location":"Бизнес центр \"Центр международной торговли\"","metro":[{"name":"Горьковская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524424","geolocation":{"latitude":"56.246255","longitude":"43.965359"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, пр-т Гагарина,59а","location":"автосалон Артан"}},{"id":"524425","geolocation":{"latitude":"56.314836","longitude":"44.001297"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Горького, 115","nearestSubway":"Горьковская","location":"Гостиница \"Ибис\"","metro":[{"name":"Горьковская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524426","geolocation":{"latitude":"56.320302","longitude":"43.947581"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, пр. Ленина, 93","location":"Гринатом"}},{"id":"524427","geolocation":{"latitude":"56.299242","longitude":"43.945304"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, пл. Комсомольская, 3а","nearestSubway":"Ленинская","location":"АЗС Газпромнефть","metro":[{"name":"Ленинская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524429","geolocation":{"latitude":"56.333779","longitude":"43.959085"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Керченская, 13","nearestSubway":"Московская","location":"БЦ \"Время\"","metro":[{"name":"Московская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524431","geolocation":{"latitude":"55.397999","longitude":"43.845366"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Арзамас","fullAddress":"Нижегородская обл., г. Арзамас, ул.Севастопольская, 27","location":"ПАО \"Газпром газораспределение\""}},{"id":"524433","geolocation":{"latitude":"56.312045","longitude":"44.037194"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, пер. Звенигородский, 8","location":"ПАО \"Газпром Газораспределение\""}},{"id":"524435","geolocation":{"latitude":"56.302617","longitude":"43.978453"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, пр-т Гагарина,17А","nearestSubway":"Горьковская","location":"Российский Государственный Университет Правосудия","metro":[{"name":"Горьковская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524436","geolocation":{"latitude":"56.150499","longitude":"44.211296"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Кстово","fullAddress":"Нижегородская обл., г. Кстово, пл. Ленина, 5А","location":"ТЦ \"Пирамида\", м-н \"Магнит\""}},{"id":"524439","geolocation":{"latitude":"56.302428","longitude":"44.029136"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул. Ванеева, 121","nearestSubway":"Горьковская","location":"Гостиница \"Сова\"","metro":[{"name":"Горьковская","line":{"name":"Автозаводская","code":"line2"},"icon":{"colorScheme":{"primary":"#EE3124","secondary":"#ACBFE0"}}}]}},{"id":"524440","geolocation":{"latitude":"56.338474","longitude":"43.838325"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Нижний Новгород","fullAddress":"Нижегородская обл., г. Нижний Новгород, ул.Мечникова, д.75","nearestSubway":"Буревестник","location":"магазин Ордер","metro":[{"name":"Буревестник","line":{"name":"Сормовско-Мещерская","code":"line1"},"icon":{"colorScheme":{"primary":"#0078BF","secondary":"#ACBFE0"}}}]}},{"id":"524441","geolocation":{"latitude":"56.296037","longitude":"42.791629"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"п","settlement":"Центральный","fullAddress":"Нижегородская обл., п. Центральный, полк Химзащиты","location":"КПП"}},{"id":"524443","geolocation":{"latitude":"56.225990","longitude":"43.396749"},"address":{"region":"Нижегородская","regionType":"обл","settlementType":"г","settlement":"Дзержинск","fullAddress":"Нижегородская обл., г. Дзержинск, ул.Свердлова, 67а","location":"Теплогаз Дзержинск"}},{"id":"524445","geolocation":{"latitude":"58.603811","longitude":"49.671912"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, ул. Московская, 31","location":"ОО \"Кировский\" Филиала Банка ГПБ (АО) \"Приволжский\""}},{"id":"524446","geolocation":{"latitude":"56.620998","longitude":"47.858358"},"address":{"region":"Марий Эл","regionType":"Респ","settlementType":"г","settlement":"Йошкар-Ола","fullAddress":"Марий Эл Респ., г. Йошкар-Ола, ул. Строителей, 95","location":"ЗАО \"Портал\""}},{"id":"524448","geolocation":{"latitude":"58.602559","longitude":"49.626458"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, ул. Московская, 106\/1","location":"Автосалон \"Фольксваген\""}},{"id":"524449","geolocation":{"latitude":"58.594142","longitude":"49.656219"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, ул. Воровского, 77","location":"ТЦ \"ЦУМ\""}},{"id":"524450","geolocation":{"latitude":"58.637733","longitude":"49.614079"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, Октябрьский пр-т, 1","location":"м-н \"Глобус\""}},{"id":"524451","geolocation":{"latitude":"58.596149","longitude":"49.658537"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, Октябрьский пр-т, 84","location":"магазин \"Все на свете\""}},{"id":"524452","geolocation":{"latitude":"58.602761","longitude":"49.597200"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, ул. Московская, 171","location":"м-н \"Глобус\""}},{"id":"524453","geolocation":{"latitude":"58.611110","longitude":"49.680716"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, ул.Ленина, 20","location":"м-н \"Глобус\""}},{"id":"524454","geolocation":{"latitude":"58.594438","longitude":"49.666657"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, ул. Воровского, 43","location":"ТД \"Европейский\", 1 этаж"}},{"id":"524455","geolocation":{"latitude":"58.597481","longitude":"49.605572"},"address":{"region":"Кировская","regionType":"обл","settlementType":"г","settlement":"Киров","fullAddress":"Кировская обл., г. Киров, ул. Воровского, 135","location":"ТЦ \"Глобус\", 2 этаж"}}]

# %%
len(ATM)
# Out:
# 100

# %%
frame = []
for i in range(0,100):
    c = []
    b = ATM[i]
    c.append(b['id'])
    c.append(b['geolocation']['latitude'])
    c.append(b['geolocation']['longitude'])
    c.append(b['address']['settlementType'])
    c.append(b['address']['settlement'])
    frame.append(c)

# %%
parser = pd.DataFrame(frame,columns = ['id', 'latitude', 'longitude', 'settlementType', 'settlement'])

# %%
parser.to_csv('parser.csv', index = False)

# %%
parser
# Out:
#         id   latitude  longitude settlementType settlement
# 0   324394  55.804936  37.589922              г     Москва
# 1   324460  55.524047  37.518347              г     Москва
# 2   324957  51.863511  54.763003              п    Каргала
# 3   324959  51.717497  55.091279              г   Оренбург
# 4   324961  51.775720  55.185184              г   Оренбург
# ..     ...        ...        ...            ...        ...
# 95  524451  58.596149  49.658537              г      Киров
# 96  524452  58.602761  49.597200              г      Киров
# 97  524453  58.611110  49.680716              г      Киров
# 98  524454  58.594438  49.666657              г      Киров
# 99  524455  58.597481  49.605572              г      Киров
#
# [100 rows x 5 columns]

# %%
parser['settlementType'].value_counts()
# Out:
# г     83
# п      9
# с      4
# д      2
# рп     2
# Name: settlementType, dtype: int64

# %%
parser[parser['settlementType'] == 'г']['settlement'].value_counts()
# Out:
# Москва             24
# Нижний Новгород    22
# Киров               9
# Оренбург            9
# Дзержинск           6
# Кстово              2
# Балахна             2
#                     2
# Лысково             1
# Арзамас             1
# Йошкар-Ола          1
# Воскресенск         1
# Ковров              1
# Химки               1
# Бузулук             1
# Name: settlement, dtype: int64

# %%
TSP_data = parser[parser['settlement'] == 'Москва'][['settlement','latitude', 'longitude']]
TSP_data.reset_index()
# Out:
#     index settlement   latitude  longitude
# 0       0     Москва  55.804936  37.589922
# 1       1     Москва  55.524047  37.518347
# 2      15     Москва  55.888256  37.589363
# 3      17     Москва  55.710687  37.670465
# 4      19     Москва  55.719987  37.776215
# 5      20     Москва  55.767332  37.524228
# 6      21     Москва  55.679895  37.568497
# 7      23     Москва  55.762399  37.619117
# 8      24     Москва  55.724124  37.825155
# 9      25     Москва  55.617276  37.715622
# 10     26     Москва  55.685320  37.540156
# 11     27     Москва  55.819392  37.578314
# 12     28     Москва  55.662136  37.547046
# 13     29     Москва  55.837380  37.744227
# 14     31     Москва  55.659622  37.747738
# 15     32     Москва  55.789856  37.631422
# 16     34     Москва  55.664472  37.599238
# 17     38     Москва  55.655923  37.541505
# 18     39     Москва  55.746299  37.546174
# 19     40     Москва  55.688862  37.540668
# 20     41     Москва  55.745904  37.559910
# ...

# %%
X=parser[parser['settlement'] == 'Москва']['latitude']
X.astype('float')
# Out:
# 0     55.804936
# 1     55.524047
# 15    55.888256
# 17    55.710687
# 19    55.719987
# 20    55.767332
# 21    55.679895
# 23    55.762399
# 24    55.724124
# 25    55.617276
# 26    55.685320
# 27    55.819392
# 28    55.662136
# 29    55.837380
# 31    55.659622
# 32    55.789856
# 34    55.664472
# 38    55.655923
# 39    55.746299
# 40    55.688862
# 41    55.745904
# 42    55.752931
# 43    55.723460
# 44    55.805275
# Name: latitude, dtype: float64

# %%
parser[parser['settlement'] == 'Москва']['latitude'].astype(float)
# Out:
# 0     55.804936
# 1     55.524047
# 15    55.888256
# 17    55.710687
# 19    55.719987
# 20    55.767332
# 21    55.679895
# 23    55.762399
# 24    55.724124
# 25    55.617276
# 26    55.685320
# 27    55.819392
# 28    55.662136
# 29    55.837380
# 31    55.659622
# 32    55.789856
# 34    55.664472
# 38    55.655923
# 39    55.746299
# 40    55.688862
# 41    55.745904
# 42    55.752931
# 43    55.723460
# 44    55.805275
# Name: latitude, dtype: float64
